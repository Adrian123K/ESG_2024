# %%
# %cd '/content/drive/MyDrive/ESG 2024/교안/실습'
# Out:
# /content/drive/MyDrive/ESG 2024/교안/실습

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/ESG 2024/교안/실습/.git/

# %%
# !git branch -M main

# %%
# !git remote add branch https://github.com/Adrian123K/ESG_2024.git

# %%
# !git pull branch main
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 0), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), 248 bytes | 4.00 KiB/s, done.
# From https://github.com/Adrian123K/ESG_2024
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> branch/main

# %%
# !cat .gitignore
# Out:
# test
# test2.ipynb
# datasets
# ref
# Simple CNN & InceptionV3.ipynb

# %%
# !echo "Simple CNN & InceptionV3.ipynb" >> .gitignore

# %%
# !sed -i '5d' .gitignore

# %%
# !cat .gitignore
# Out:
# test
# test2.ipynb
# datasets
# ref

# %%
# !git config --global user.email "seojun.a.kim@gmail.com"

# %%
# !git config --global user.name "ASK"
